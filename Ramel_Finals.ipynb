# %%
# !pip install streamlit pyngrok -q

# %%
# %%writefile RamelFinals_app.py

import streamlit as st
import pandas as pd
import plotly.graph_objects as go

st.set_page_config(layout="wide")
@st.cache_data
def load_data():
    url = 'https://raw.githubusercontent.com/Parhelion2222/Finals/main/archive%20(2)/mental_health.csv'
    df = pd.read_csv(url)
    return df

df = load_data()

st.title("Mental Health Dashboard")
st.dataframe(df)
st.write(df.describe())
# Out:
# Overwriting RamelFinals_app.py

# %%
import os

# Clone your repo (use your token)
# !git clone https://<YOUR_TOKEN>@github.com/Parhelion2222/Finals.git

# Copy app.py into the repo folder
# !cp app.py Finals/app.py

# Go into the repo
os.chdir('/content/Finals')

# Set git identity
# !git config user.email "kurtramel304@gmail.com"
# !git config user.name "Parhelion2222"

# Push to GitHub
# !git add app.py
# !git commit -m "Add Streamlit app"
# !git push origin main
# Out:
# /bin/bash: line 1: YOUR_TOKEN: No such file or directory
# cp: cannot create regular file 'Finals/app.py': No such file or directory
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	RamelFinals_app.py
#
# nothing added to commit but untracked files present (use "git add" to track)
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
from google.colab import files
files.download("RamelFinals_app.py")
